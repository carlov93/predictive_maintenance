# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import signal
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller

# %%
path_original = "../../data/artifical_signals/NewBlade_with_sine.csv"
df_original = pd.read_csv(path_original)
df_original = df_original.diff(periods=1)
df_original["timestamp"]=range(df_original.shape[0])

# %%
fig, axes = plt.subplots(2, 4, figsize=(15,7.5), dpi=200)
ax = axes.ravel()
plt.subplots_adjust(hspace=0.2, wspace=0.6)
for i in range(1,9):
    sns.lineplot(x=df_original.iloc[:,0] , y=df_original.iloc[:,i], ax=ax[i-1])
#plt.savefig("../graphs/raw_sensor_data.png")
plt.show()

# %%
fig, axes = plt.subplots(2, 4, figsize=(15,7.5), dpi=200)
ax = axes.ravel()
plt.subplots_adjust(hspace=0.2, wspace=0.6)
for i in range(1,9):
    sns.lineplot(x=df_original.iloc[:,0] , y=df_original.iloc[:,i], ax=ax[i-1])
#plt.savefig("../graphs/raw_sensor_data.png")
plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(15,7.5), dpi=200)
plt.subplots_adjust(hspace=0.2, wspace=0.6)
sns.lineplot(x=df_original.iloc[:,0] , y=df_original.iloc[:,3])
#plt.savefig("../graphs/raw_sensor_data.png")
plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(15,7.5), dpi=200)
plt.subplots_adjust(hspace=0.2, wspace=0.6)
sns.lineplot(x=df_original.iloc[:,0] , y=df_original.iloc[:,3])
#plt.savefig("../graphs/raw_sensor_data.png")
plt.show()
