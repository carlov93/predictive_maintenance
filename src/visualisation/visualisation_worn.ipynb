# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Visualisation - Worn Blade

# %%
path_original = "../../data/vega_shrinkwrapper_original/WornBlade001_new_column_name.csv"

# %%
df_original = pd.read_csv(path_original)

# %% [markdown]
# ## Histogramm - orignial data

# %%
fig, axes = plt.subplots(2, 4, figsize=(15,15))
ax = axes.ravel()
plt.subplots_adjust(hspace=0.2, wspace=0.4)
for i in range(8):
    sns.distplot(df_original.iloc[:,i], ax=ax[i])
plt.show()

# %% [markdown]
# ## Scatterplot - original data

# %%
fig, axes = plt.subplots(2, 4, figsize=(15,15))
ax = axes.ravel()
plt.subplots_adjust(hspace=0.2, wspace=0.4)
for i in range(0,8):
    sns.scatterplot(x=df_original.iloc[:,0] , y=df_original.iloc[:,i], ax=ax[i])
plt.show()
