# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import signal
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller
import numpy as np

# %% [markdown]
# ### Dataset until first failure contains around 173.000 observations:

# %%
path_original = "../../../data/phm_data_challenge/01_M01_DC_preprocessed.csv"
df_original = pd.read_csv(path_original)
df_original.shape
# Out:
# (173175, 26)

# %%
fig, axes = plt.subplots(5, 2, figsize=(30,20), sharex=True) # , dpi=200, 
ax = axes.ravel()
plt.subplots_adjust(hspace=0.2, wspace=0.6)
for i in range(0,10):
    sns.lineplot(x=df_original.iloc[:,2], y=df_original.iloc[:,i], ax=ax[i])
#plt.savefig("../graphs/raw_sensor_data.png")
#ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
#fig.tight_layout()
plt.subplots_adjust(wspace=0.2, hspace=0.2)
plt.show()

# %%
fig, axes = plt.subplots(5, 2, figsize=(30,20), sharex=True) # , dpi=200, 
ax = axes.ravel()
plt.subplots_adjust(hspace=0.2, wspace=0.6)
for i in range(10,20):
    sns.lineplot(x=df_original.iloc[:,2], y=df_original.iloc[:,i], ax=ax[i-10])
#plt.savefig("../graphs/raw_sensor_data.png")
#ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
#fig.tight_layout()
plt.subplots_adjust(wspace=0.2, hspace=0.2)
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(30,20), sharex=True) # , dpi=200, 
ax = axes.ravel()
plt.subplots_adjust(hspace=0.2, wspace=0.6)
for i in range(20,26):
    sns.lineplot(x=df_original.iloc[:,2], y=df_original.iloc[:,i], ax=ax[i-20])
#plt.savefig("../graphs/raw_sensor_data.png")
#ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
#fig.tight_layout()
plt.subplots_adjust(wspace=0.2, hspace=0.2)
plt.show()

# %% [markdown]
# ## Augmented Dickey-Fuller Test for Testing Stationarity
# If failed to be rejected, it suggests the time series has a unit root, meaning it is non-stationary. It has some time dependent structure. <br>
# p-value > 0.05: Fail to reject the null hypothesis (H0), the data has a unit root and is non-stationary. <br>
# Following time series are non-stationary:
# - cut torque
# - cut position
# - film position

# %%
for i in range(5, len(df_original.columns)):
    time_series = df_original.iloc[:,i].values
    result = adfuller(time_series)
    print("Test for: {}".format(df_original.columns[i]))
    print('p-value: {}'.format(result[1]))
    if result[1] >= 0.05:
        print("Time series is non-stationary")
    else:
        print("Time series is stationary")
    print('-'*10)
# Out:
# Test for: IONGAUGEPRESSURE
# p-value: 0.0
# Time series is stationary
# ----------
# Test for: ETCHBEAMVOLTAGE
# p-value: 0.0
# Time series is stationary
# ----------
# Test for: ETCHBEAMCURRENT
# p-value: 0.0
# Time series is stationary
# ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-503af44951a4> in <module>
#       1 for i in range(5, len(df_original.columns)):
#       2     time_series = df_original.iloc[:,i].values
# ----> 3     result = adfuller(time_series)
#       4     print("Test for: {}".format(df_original.columns[i]))
#       5     print('p-value: {}'.format(result[1]))
#
# ~/jupyter_notebooks/masterarbeit/venv_pm/lib/python3.6/site-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     255         if not regresults:
#     256             icbest, bestlag = _autolag(OLS, xdshort, fullRHS, startlag,
# --> 257                                        maxlag, autolag)
#     258         else:
#     259             icbest, bestlag, alres = _autolag(OLS, xdshort, fullRHS, startlag,
#
# ~/jupyter_notebooks/masterarbeit/venv_pm/lib/python3.6/site-packages/statsmodels/tsa/stattools.py in _autolag(mod, endog, exog, startlag, maxlag, method, modargs, fitargs, regresults)
#      91     for lag in range(startlag, startlag + maxlag + 1):
#      92         mod_instance = mod(endog, exog[:, :lag], *modargs)
# ---> 93         results[lag] = mod_instance.fit()
#      94
#      95     if method == "aic":
#
# ~/jupyter_notebooks/masterarbeit/venv_pm/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#     288                     hasattr(self, 'rank')):
#     289
# --> 290                 self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#     291                 self.normalized_cov_params = np.dot(
#     292                     self.pinv_wexog, np.transpose(self.pinv_wexog))
#
# ~/jupyter_notebooks/masterarbeit/venv_pm/lib/python3.6/site-packages/statsmodels/tools/tools.py in pinv_extended(X, rcond)
#     366     X = np.asarray(X)
#     367     X = X.conjugate()
# --> 368     u, s, vt = np.linalg.svd(X, 0)
#     369     s_orig = np.copy(s)
#     370     m = u.shape[0]
#
# ~/jupyter_notebooks/masterarbeit/venv_pm/lib/python3.6/site-packages/numpy/linalg/linalg.py in svd(a, full_matrices, compute_uv)
#    1610
#    1611         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1612         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1613         u = u.astype(result_t, copy=False)
#    1614         s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Select first 20.000 observations to visualise dataset:

# %%
df_original = df_original.iloc[0:20000,:]
df_original.shape
# Out:
# (20000, 25)

# %%
fig, axes = plt.subplots(5, 2, figsize=(30,20), sharex=True) # , dpi=200, 
ax = axes.ravel()
plt.subplots_adjust(hspace=0.2, wspace=0.6)
for i in range(0,10):
    sns.lineplot(x=df_original.iloc[:,1], y=df_original.iloc[:,i], ax=ax[i])
#plt.savefig("../graphs/raw_sensor_data.png")
#ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
#fig.tight_layout()
plt.subplots_adjust(wspace=0.2, hspace=0.2)
plt.show()

# %%
fig, axes = plt.subplots(5, 2, figsize=(30,20), sharex=True) # , dpi=200, 
ax = axes.ravel()
plt.subplots_adjust(hspace=0.2, wspace=0.6)
for i in range(10,20):
    sns.lineplot(x=df_original.iloc[:,1], y=df_original.iloc[:,i], ax=ax[i-10])
#plt.savefig("../graphs/raw_sensor_data.png")
#ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
#fig.tight_layout()
plt.subplots_adjust(wspace=0.2, hspace=0.2)
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(30,20), sharex=True) # , dpi=200, 
ax = axes.ravel()
plt.subplots_adjust(hspace=0.2, wspace=0.6)
for i in range(20,25):
    sns.lineplot(x=df_original.iloc[:,1], y=df_original.iloc[:,i], ax=ax[i-20])
#plt.savefig("../graphs/raw_sensor_data.png")
#ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
#fig.tight_layout()
plt.subplots_adjust(wspace=0.2, hspace=0.2)
plt.show()

# %% [markdown]
# ## Correlation of sensor time series

# %%
corr = df_original.corr()
fig = plt.figure(figsize=(10,4.5), dpi=120)
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df_original.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df_original.columns)
ax.set_yticklabels(df_original.columns)
plt.show()

# %% [markdown]
# ## Autocorrelation

# %%
fig, axes = plt.subplots(6, 4, figsize=(15,7.5), dpi=200)
ax = axes.ravel()
plt.subplots_adjust(hspace=0.2, wspace=0.4)
for i in range(0,24):
    plot_acf(df_original.iloc[:,i], lags=20, ax=ax[i-1])
    ax[i-1].set_title(df_original.columns[i])
#plt.savefig("../graphs/raw_sensor_data_autocorrelation.png")
plt.subplots_adjust(wspace=0.2, hspace=0.8)
plt.show()

# %% [markdown]
# ## Histogramm

# %%
fig, axes = plt.subplots(6, 4, figsize=(25,18), dpi=200)
ax = axes.ravel()
plt.subplots_adjust(hspace=0.2, wspace=0.4)
for i in range(3, 24):
    sns.distplot(df_original.iloc[:,i], ax=ax[i-3])
#plt.savefig("../graphs/raw_sensor_data_histogramm.png")
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()
