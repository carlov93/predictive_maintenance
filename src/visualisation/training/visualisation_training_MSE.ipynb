# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Visualisation of loss during training
# ### MSE Loss Function - with tanh activation function

# %%
history = pd.read_csv("../files/history_MSE_with_tanh.csv",sep=";")
f, ax = plt.subplots(figsize=(10, 10))
sns.lineplot(data=history, x="epoch", y="training", ax=ax, label="training")
sns.lineplot(data=history, x="epoch", y="validation", ax=ax, label="validation")
ax.set(xlabel='epoch', ylabel='loss')
plt.show()

# %% [markdown]
# ### Maximum Likelihood Loss Function
